# %% [markdown]
# ## Finde five five-letter words with 25 different characters
#
# ### First approach
#
# No optimization. Every word has the same value, despite how odd it is.

# %% [markdown]
# #### Loading the needed modules

# %%
import pulp as plp
import pandas as pd
import numpy as np

# %% [markdown]
# #### Loading and processing the word list
#
# Source of word list: https://github.com/dwyl/english-words

# %%
# loading words
file = 'words_alpha.txt'
df = pd.read_csv(file, names=['word'])

# get length of each word
df['length'] = df['word'].apply(lambda x: len(str(x)))

# keep only words of length 5
dff = df[df.length == 5].copy()

# filter out words which do not contain vows
dff = dff[dff['word'].str.contains('a|e|i|o|u|y')]

# get number of unique characters of each word
dff['count unique'] = dff['word'].apply(lambda word: len(set(word)))

# keep only words with 5 unique characters
word_list = dff[dff['count unique'] == 5]['word'].values

# return length of lists
print(f'Original list has length {len(df)}')
print(f'Filtered list of five letter words has length {len(dff)}')
print(f'Filtered list with unique five letter characters has length {len(word_list)}')
# Out:
# Original list has length 370105
# Filtered list of five letter words has length 15912
# Filtered list with unique five letter characters has length 10172

# %% [markdown]
# #### Solving the ILP problem
#
# This approach gives a possible of potentially many solutions

# %%
# set variables
variables = plp.LpVariable.dict('words', (word_list), lowBound=0, upBound=1, cat='Binary')

# initialize problem
prob = plp.LpProblem('Find_five_words')

# constraint 1: only five words
prob += plp.lpSum([variables[word] for word in word_list]) == 5

# constraint 2: each char is allowed to occur only once
for char in 'abcdefghijklmnopqrstuvwxyz':
    prob += plp.lpSum([variables[word] for word in word_list if char in word]) <= 1

prob.solve()

# returning the solution
solution = [word for word in word_list if variables[word].value() == 1.0]
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/0ba961bbfe52462787f2e414eee8e872-pulp.lp -o /tmp/0ba961bbfe52462787f2e414eee8e872-pulp.sol
# Reading problem data from '/tmp/0ba961bbfe52462787f2e414eee8e872-pulp.lp'...
# 27 rows, 10173 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# 22398 lines were read
# GLPK Integer Optimizer 5.0
# 27 rows, 10173 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10172 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10172 columns, 61032 non-zeros
#       0: obj =   0.000000000e+00 inf =   2.400e+01 (6)
#      57: obj =   0.000000000e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    57: mip =     not found yet >=              -inf        (1; 0)
# +   145: >>>>>   0.000000000e+00 >=   0.000000000e+00   0.0% (12; 0)
# +   145: mip =   0.000000000e+00 >=     tree is empty   0.0% (0; 23)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 14.0 Mb (14712852 bytes)
# Writing MIP solution to '/tmp/0ba961bbfe52462787f2e414eee8e872-pulp.sol'...

# %%
solution
# Out:
# ['frack', 'jowly', 'pbxes', 'vingt', 'zhmud']

# %% [markdown]
# ## Getting more interesting solutions
#
# ### Using Pulp for optimization
#
# #### Load a word frequency dataset
# Loading Google's NGram dataset to retrieve the word frequencies for optimization
#
# Source: https://www.kaggle.com/datasets/wheelercode/english-word-frequency-list

# %%
# load Google Books Ngram dataset from Kaggle
file_freq = 'ngram_freq.csv'
# file_freq = 'unigram_freq.csv'
df_freq = pd.read_csv(file_freq)

# get length of words
df_freq['length'] = df_freq['word'].apply(lambda x: len(str(x)))
dff_freq = df_freq[df_freq['length'] == 5].copy()

# get number of unique characters of each word
dff_freq['length'] = dff_freq['word'].apply(lambda word: len(set(word)))

# keep only words with 5 unique characters
dfff_freq = dff_freq[dff_freq.length == 5].reset_index(drop=True)

# transfer data into dictionary for later look up
freq_dict = {dfff_freq.loc[i, 'word']: dfff_freq.loc[i, 'count'] for i in dfff_freq.index}

# return length of lists
print(f'Original list has length {len(df_freq)}')
print(f'Filtered list with unique five letter characters has length {len(freq_dict)}')
# Out:
# Original list has length 9244879
# Filtered list with unique five letter characters has length 427383

# %% [markdown]
# #### Adding the frequencies to the word list
#
# Now we match the words of the original list with the count frequencies found in the NGram dataset. Word which are not included in the NGram dataset are given the count 1.

# %%
word_dict = {}
not_found_count = 0

for word in word_list:
    try: 
        # try to get counts from NGram dataset
        count = freq_dict[word]
        word_dict[word] = count
    except KeyError:
        # if key is not found in NGram dataset, add it to list with a count of 1
        word_dict[word] = 1
        not_found_count += 1

word_list = list(word_dict.keys())
len(word_dict), not_found_count
# Out:
# (10172, 119)

# %% [markdown]
# #### Solve the adapted problem
#
# Finding the optimal solution to the problem. We take the logarithm of the count frequencies to get better solutions since the frequencies range over several magnitutes. After finding an optimal solution which maximizes the word frequency, we exclude the word with the highes frequency count from the problem and re-run the code.

# %%
# set variables
variables = plp.LpVariable.dict('words', (word_list), lowBound=0, upBound=1, cat='Binary')

# initialize problem
prob = plp.LpProblem('Find_five_words', plp.LpMaximize)

# objective function
prob += plp.lpSum([variables[word] * np.log(word_dict[word]) for word in word_list])

# constraint 1: only five words
prob += plp.lpSum([variables[word] for word in word_list]) == 5

# constraint 2: each char is allowed to occur only once
for char in 'abcdefghijklmnopqrstuvwxyz':
    prob += plp.lpSum([variables[word] for word in word_list if char in word]) <= 1
          
solutions = []
   
# continue solving while not all solutions are found
while True:
    prob.solve()
    
    # break if ILP solution is not optimal
    if plp.LpStatus[prob.status] != "Optimal":
        break
        
    # retrieve results       
    results = [word for word in word_list if variables[word].value() == 1.0]
     
    # find result with most counts for exclusion
    results_dict = {r: word_dict[r] for r in results}        
    exclude = max(results_dict, key=results_dict.get)
        
    # exclude word from problem
    prob += plp.lpSum(variables[exclude]) == 0 
    
    # append new results to solutions list
    solutions.append(results)
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/59f7da6e6e9747ec8bbeef854ae07a40-pulp.lp -o /tmp/59f7da6e6e9747ec8bbeef854ae07a40-pulp.sol
# Reading problem data from '/tmp/59f7da6e6e9747ec8bbeef854ae07a40-pulp.lp'...
# 27 rows, 10172 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# 27422 lines were read
# GLPK Integer Optimizer 5.0
# 27 rows, 10172 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10172 columns, 61032 non-zeros
# 10172 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10172 columns, 61032 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      46: obj =   5.092732070e+01 inf =   6.277e-18 (0)
# *    84: obj =   7.097035546e+01 inf =   1.445e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    84: mip =     not found yet <=              +inf        (1; 0)
# +   377: >>>>>   4.715040760e+01 <=   6.890079229e+01  46.1% (24; 4)
# +   387: >>>>>   6.087839747e+01 <=   6.873559855e+01  12.9% (20; 10)
# +   464: >>>>>   6.373069163e+01 <=   6.794490156e+01   6.6% (8; 37)
# +   655: mip =   6.373069163e+01 <=     tree is empty   0.0% (0; 81)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.4 secs
# Memory used: 15.5 Mb (16270536 bytes)
# Writing MIP solution to '/tmp/59f7da6e6e9747ec8bbeef854ae07a40-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/73f78e35922f4d1cbf8d006703911f58-pulp.lp -o /tmp/73f78e35922f4d1cbf8d006703911f58-pulp.sol
# Reading problem data from '/tmp/73f78e35922f4d1cbf8d006703911f58-pulp.lp'...
# 28 rows, 10172 columns, 61033 non-zeros
# 10172 integer variables, all of which are binary
# 27423 lines were read
# GLPK Integer Optimizer 5.0
# 28 rows, 10172 columns, 61033 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10171 columns, 61026 non-zeros
# 10171 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10171 columns, 61026 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    70: obj =   7.095823121e+01 inf =   1.103e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    70: mip =     not found yet <=              +inf        (1; 0)
# +  1493: >>>>>   6.087839747e+01 <=   6.332933557e+01   4.0% (74; 34)
# +  1623: mip =   6.087839747e+01 <=     tree is empty   0.0% (0; 219)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.0 secs
# Memory used: 19.6 Mb (20565987 bytes)
# Writing MIP solution to '/tmp/73f78e35922f4d1cbf8d006703911f58-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/e3de519066aa4a0080c35cb9c3365fb7-pulp.lp -o /tmp/e3de519066aa4a0080c35cb9c3365fb7-pulp.sol
# Reading problem data from '/tmp/e3de519066aa4a0080c35cb9c3365fb7-pulp.lp'...
# 29 rows, 10172 columns, 61034 non-zeros
# 10172 integer variables, all of which are binary
# 27424 lines were read
# GLPK Integer Optimizer 5.0
# 29 rows, 10172 columns, 61034 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10170 columns, 61020 non-zeros
# 10170 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10170 columns, 61020 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    70: obj =   7.095823121e+01 inf =   1.103e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    70: mip =     not found yet <=              +inf        (1; 0)
# +  1138: >>>>>   5.932407216e+01 <=   6.440559236e+01   8.6% (65; 23)
# +  1502: mip =   5.932407216e+01 <=     tree is empty   0.0% (0; 217)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.1 secs
# Memory used: 18.7 Mb (19638624 bytes)
# Writing MIP solution to '/tmp/e3de519066aa4a0080c35cb9c3365fb7-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/f1344c27b61b4c5ab17e519e6f8ed318-pulp.lp -o /tmp/f1344c27b61b4c5ab17e519e6f8ed318-pulp.sol
# Reading problem data from '/tmp/f1344c27b61b4c5ab17e519e6f8ed318-pulp.lp'...
# 30 rows, 10172 columns, 61035 non-zeros
# 10172 integer variables, all of which are binary
# 27425 lines were read
# GLPK Integer Optimizer 5.0
# 30 rows, 10172 columns, 61035 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10169 columns, 61014 non-zeros
# 10169 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10169 columns, 61014 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    74: obj =   7.038693908e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    74: mip =     not found yet <=              +inf        (1; 0)
# +   967: >>>>>   5.021631740e+01 <=   6.465855773e+01  28.8% (53; 17)
# +  1093: >>>>>   5.879639390e+01 <=   6.427334327e+01   9.3% (50; 34)
# +  1210: mip =   5.879639390e+01 <=     tree is empty   0.0% (0; 173)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.8 secs
# Memory used: 17.6 Mb (18453409 bytes)
# Writing MIP solution to '/tmp/f1344c27b61b4c5ab17e519e6f8ed318-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/2359a64b88d34ad18087a89342a96e45-pulp.lp -o /tmp/2359a64b88d34ad18087a89342a96e45-pulp.sol
# Reading problem data from '/tmp/2359a64b88d34ad18087a89342a96e45-pulp.lp'...
# 31 rows, 10172 columns, 61036 non-zeros
# 10172 integer variables, all of which are binary
# 27426 lines were read
# GLPK Integer Optimizer 5.0
# 31 rows, 10172 columns, 61036 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10168 columns, 61008 non-zeros
# 10168 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10168 columns, 61008 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +   247: >>>>>   5.835624047e+01 <=   6.926062373e+01  18.7% (12; 3)
# +   673: >>>>>   5.836936678e+01 <=   5.836936678e+01   0.0% (1; 74)
# +   673: mip =   5.836936678e+01 <=     tree is empty   0.0% (0; 83)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.5 secs
# Memory used: 15.2 Mb (15940220 bytes)
# Writing MIP solution to '/tmp/2359a64b88d34ad18087a89342a96e45-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/615e63904ea4461da08107bb774443ba-pulp.lp -o /tmp/615e63904ea4461da08107bb774443ba-pulp.sol
# Reading problem data from '/tmp/615e63904ea4461da08107bb774443ba-pulp.lp'...
# 32 rows, 10172 columns, 61037 non-zeros
# 10172 integer variables, all of which are binary
# 27427 lines were read
# GLPK Integer Optimizer 5.0
# 32 rows, 10172 columns, 61037 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10167 columns, 61002 non-zeros
# 10167 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10167 columns, 61002 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +   247: >>>>>   5.835624047e+01 <=   6.926062373e+01  18.7% (12; 3)
# +   669: mip =   5.835624047e+01 <=     tree is empty   0.0% (0; 83)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.5 secs
# Memory used: 15.2 Mb (15939871 bytes)
# Writing MIP solution to '/tmp/615e63904ea4461da08107bb774443ba-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/57c85a3cea3940edab5762138af6e9b8-pulp.lp -o /tmp/57c85a3cea3940edab5762138af6e9b8-pulp.sol
# Reading problem data from '/tmp/57c85a3cea3940edab5762138af6e9b8-pulp.lp'...
# 33 rows, 10172 columns, 61038 non-zeros
# 10172 integer variables, all of which are binary
# 27428 lines were read
# GLPK Integer Optimizer 5.0
# 33 rows, 10172 columns, 61038 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10166 columns, 60996 non-zeros
# 10166 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10166 columns, 60996 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +  1247: >>>>>   4.099733902e+01 <=   6.041711248e+01  47.4% (52; 28)
# +  1427: >>>>>   4.203415367e+01 <=   5.960048910e+01  41.8% (73; 32)
# +  1472: >>>>>   4.234411213e+01 <=   5.879282326e+01  38.8% (69; 37)
# +  1595: >>>>>   5.547580726e+01 <=   5.731643396e+01   3.3% (61; 52)
# +  1620: >>>>>   5.625837797e+01 <=   5.658171099e+01   0.6% (16; 129)
# +  1625: mip =   5.625837797e+01 <=     tree is empty   0.0% (0; 225)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.2 secs
# Memory used: 19.7 Mb (20699000 bytes)
# Writing MIP solution to '/tmp/57c85a3cea3940edab5762138af6e9b8-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/f9ba275cfea74629a96ba38de6b3d613-pulp.lp -o /tmp/f9ba275cfea74629a96ba38de6b3d613-pulp.sol
# Reading problem data from '/tmp/f9ba275cfea74629a96ba38de6b3d613-pulp.lp'...
# 34 rows, 10172 columns, 61039 non-zeros
# 10172 integer variables, all of which are binary
# 27429 lines were read
# GLPK Integer Optimizer 5.0
# 34 rows, 10172 columns, 61039 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10165 columns, 60990 non-zeros
# 10165 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10165 columns, 60990 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +  1243: >>>>>   4.099733902e+01 <=   6.041711248e+01  47.4% (52; 28)
# +  1422: >>>>>   4.203415367e+01 <=   5.960048910e+01  41.8% (73; 32)
# +  1467: >>>>>   4.234411213e+01 <=   5.879282326e+01  38.8% (69; 37)
# +  1534: >>>>>   5.560845051e+01 <=   5.846099247e+01   5.1% (71; 43)
# +  1601: mip =   5.560845051e+01 <=     tree is empty   0.0% (0; 227)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 19.9 Mb (20827163 bytes)
# Writing MIP solution to '/tmp/f9ba275cfea74629a96ba38de6b3d613-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/d79587d259884a3dabcb5c9d9d52bfb1-pulp.lp -o /tmp/d79587d259884a3dabcb5c9d9d52bfb1-pulp.sol
# Reading problem data from '/tmp/d79587d259884a3dabcb5c9d9d52bfb1-pulp.lp'...
# 35 rows, 10172 columns, 61040 non-zeros
# 10172 integer variables, all of which are binary
# 27430 lines were read
# GLPK Integer Optimizer 5.0
# 35 rows, 10172 columns, 61040 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10164 columns, 60984 non-zeros
# 10164 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10164 columns, 60984 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +  1243: >>>>>   4.099733902e+01 <=   6.041711248e+01  47.4% (52; 28)
# +  1422: >>>>>   4.203415367e+01 <=   5.960048910e+01  41.8% (73; 32)
# +  1467: >>>>>   4.234411213e+01 <=   5.879282326e+01  38.8% (69; 37)
# +  1582: >>>>>   5.547580726e+01 <=   5.731643396e+01   3.3% (61; 52)
# +  1592: >>>>>   5.556276707e+01 <=   5.699386452e+01   2.6% (20; 124)
# +  1628: mip =   5.556276707e+01 <=     tree is empty   0.0% (0; 225)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 19.9 Mb (20818782 bytes)
# Writing MIP solution to '/tmp/d79587d259884a3dabcb5c9d9d52bfb1-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/bd2131838f144163b923791ee1f62bf9-pulp.lp -o /tmp/bd2131838f144163b923791ee1f62bf9-pulp.sol
# Reading problem data from '/tmp/bd2131838f144163b923791ee1f62bf9-pulp.lp'...
# 36 rows, 10172 columns, 61041 non-zeros
# 10172 integer variables, all of which are binary
# 27431 lines were read
# GLPK Integer Optimizer 5.0
# 36 rows, 10172 columns, 61041 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10163 columns, 60978 non-zeros
# 10163 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10163 columns, 60978 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +  1431: >>>>>   4.203415367e+01 <=   6.019681733e+01  43.2% (72; 30)
# +  1514: >>>>>   4.234411213e+01 <=   5.863347718e+01  38.5% (64; 42)
# +  1617: >>>>>   5.547580726e+01 <=   5.731643396e+01   3.3% (68; 50)
# +  1670: mip =   5.547580726e+01 <=     tree is empty   0.0% (0; 233)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 19.5 Mb (20399673 bytes)
# Writing MIP solution to '/tmp/bd2131838f144163b923791ee1f62bf9-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/d7e92a0354484175885eb10c9bf27709-pulp.lp -o /tmp/d7e92a0354484175885eb10c9bf27709-pulp.sol
# Reading problem data from '/tmp/d7e92a0354484175885eb10c9bf27709-pulp.lp'...
# 37 rows, 10172 columns, 61042 non-zeros
# 10172 integer variables, all of which are binary
# 27432 lines were read
# GLPK Integer Optimizer 5.0
# 37 rows, 10172 columns, 61042 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10162 columns, 60972 non-zeros
# 10162 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10162 columns, 60972 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +   734: >>>>>   5.256865312e+01 <=   6.168690577e+01  17.3% (43; 11)
# +  1208: >>>>>   5.507140593e+01 <=   5.507140593e+01   0.0% (22; 91)
# +  1208: mip =   5.507140593e+01 <=     tree is empty   0.0% (0; 189)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.9 secs
# Memory used: 17.3 Mb (18176072 bytes)
# Writing MIP solution to '/tmp/d7e92a0354484175885eb10c9bf27709-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/b275b54a268c4f95a9785007ef8b8ca0-pulp.lp -o /tmp/b275b54a268c4f95a9785007ef8b8ca0-pulp.sol
# Reading problem data from '/tmp/b275b54a268c4f95a9785007ef8b8ca0-pulp.lp'...
# 38 rows, 10172 columns, 61043 non-zeros
# 10172 integer variables, all of which are binary
# 27433 lines were read
# GLPK Integer Optimizer 5.0
# 38 rows, 10172 columns, 61043 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10161 columns, 60966 non-zeros
# 10161 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10161 columns, 60966 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.038693908e+01 inf =   2.352e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +   693: >>>>>   5.256865312e+01 <=   6.168690577e+01  17.3% (38; 11)
# +  1202: >>>>>   5.260870565e+01 <=   5.260870565e+01 < 0.1% (1; 152)
# +  1202: mip =   5.260870565e+01 <=     tree is empty   0.0% (0; 175)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.0 secs
# Memory used: 17.3 Mb (18175723 bytes)
# Writing MIP solution to '/tmp/b275b54a268c4f95a9785007ef8b8ca0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/e3070a3b792e45569103302fed4c7641-pulp.lp -o /tmp/e3070a3b792e45569103302fed4c7641-pulp.sol
# Reading problem data from '/tmp/e3070a3b792e45569103302fed4c7641-pulp.lp'...
# 39 rows, 10172 columns, 61044 non-zeros
# 10172 integer variables, all of which are binary
# 27434 lines were read
# GLPK Integer Optimizer 5.0
# 39 rows, 10172 columns, 61044 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10160 columns, 60960 non-zeros
# 10160 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10160 columns, 60960 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    70: obj =   7.027939000e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    70: mip =     not found yet <=              +inf        (1; 0)
# +   623: >>>>>   4.613963354e+01 <=   6.516881449e+01  41.2% (43; 9)
# +  1126: >>>>>   4.988875756e+01 <=   5.937312104e+01  19.0% (59; 35)
# +  1209: >>>>>   5.256865312e+01 <=   5.869162474e+01  11.6% (50; 63)
# +  1481: mip =   5.256865312e+01 <=     tree is empty   0.0% (0; 239)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 16.5 Mb (17327336 bytes)
# Writing MIP solution to '/tmp/e3070a3b792e45569103302fed4c7641-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/bb3460b9d415407b9abf0bfd323df338-pulp.lp -o /tmp/bb3460b9d415407b9abf0bfd323df338-pulp.sol
# Reading problem data from '/tmp/bb3460b9d415407b9abf0bfd323df338-pulp.lp'...
# 40 rows, 10172 columns, 61045 non-zeros
# 10172 integer variables, all of which are binary
# 27435 lines were read
# GLPK Integer Optimizer 5.0
# 40 rows, 10172 columns, 61045 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10159 columns, 60954 non-zeros
# 10159 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10159 columns, 60954 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      37: obj =   4.799944815e+01 inf =   0.000e+00 (0)
# *    73: obj =   7.025902672e+01 inf =   3.214e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    73: mip =     not found yet <=              +inf        (1; 0)
# +   711: >>>>>   4.703876094e+01 <=   6.834356693e+01  45.3% (29; 14)
# +  1202: >>>>>   4.967851724e+01 <=   6.312886994e+01  27.1% (55; 31)
# +  1529: >>>>>   4.988875757e+01 <=   5.981414301e+01  19.9% (60; 52)
# +  1800: >>>>>   5.021631740e+01 <=   5.671268935e+01  12.9% (48; 85)
# +  2114: mip =   5.021631740e+01 <=     tree is empty   0.0% (0; 283)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.7 secs
# Memory used: 16.8 Mb (17588441 bytes)
# Writing MIP solution to '/tmp/bb3460b9d415407b9abf0bfd323df338-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/ed5195eb9be0434abbe907426b38caef-pulp.lp -o /tmp/ed5195eb9be0434abbe907426b38caef-pulp.sol
# Reading problem data from '/tmp/ed5195eb9be0434abbe907426b38caef-pulp.lp'...
# 41 rows, 10172 columns, 61046 non-zeros
# 10172 integer variables, all of which are binary
# 27436 lines were read
# GLPK Integer Optimizer 5.0
# 41 rows, 10172 columns, 61046 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10158 columns, 60948 non-zeros
# 10158 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10158 columns, 60948 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      45: obj =   5.410105819e+01 inf =   0.000e+00 (0)
# *    80: obj =   7.025902672e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    80: mip =     not found yet <=              +inf        (1; 0)
# +  1211: >>>>>   4.099733902e+01 <=   5.996425272e+01  46.3% (46; 27)
# +  1352: >>>>>   4.988875757e+01 <=   5.951092083e+01  19.3% (68; 33)
# +  1972: mip =   4.988875757e+01 <=     tree is empty   0.0% (0; 275)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.4 secs
# Memory used: 18.6 Mb (19492440 bytes)
# Writing MIP solution to '/tmp/ed5195eb9be0434abbe907426b38caef-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/4e790e5cb24d44a09ffbf0ffcafbd44c-pulp.lp -o /tmp/4e790e5cb24d44a09ffbf0ffcafbd44c-pulp.sol
# Reading problem data from '/tmp/4e790e5cb24d44a09ffbf0ffcafbd44c-pulp.lp'...
# 42 rows, 10172 columns, 61047 non-zeros
# 10172 integer variables, all of which are binary
# 27437 lines were read
# GLPK Integer Optimizer 5.0
# 42 rows, 10172 columns, 61047 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10157 columns, 60942 non-zeros
# 10157 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10157 columns, 60942 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      45: obj =   5.410105819e+01 inf =   2.054e-15 (0)
# *    85: obj =   7.025902672e+01 inf =   4.690e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    85: mip =     not found yet <=              +inf        (1; 0)
# +   680: >>>>>   4.466076138e+01 <=   6.332609082e+01  41.8% (30; 13)
# +  1321: >>>>>   4.866489231e+01 <=   5.404462675e+01  11.1% (30; 49)
# +  1521: mip =   4.866489231e+01 <=     tree is empty   0.0% (0; 177)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.1 secs
# Memory used: 17.0 Mb (17781353 bytes)
# Writing MIP solution to '/tmp/4e790e5cb24d44a09ffbf0ffcafbd44c-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/d155278c9b804cfb95d42e2895c6e0cf-pulp.lp -o /tmp/d155278c9b804cfb95d42e2895c6e0cf-pulp.sol
# Reading problem data from '/tmp/d155278c9b804cfb95d42e2895c6e0cf-pulp.lp'...
# 43 rows, 10172 columns, 61048 non-zeros
# 10172 integer variables, all of which are binary
# 27438 lines were read
# GLPK Integer Optimizer 5.0
# 43 rows, 10172 columns, 61048 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10156 columns, 60936 non-zeros
# 10156 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10156 columns, 60936 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      45: obj =   5.410105819e+01 inf =   2.054e-15 (0)
# *    85: obj =   7.025902672e+01 inf =   4.690e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    85: mip =     not found yet <=              +inf        (1; 0)
# +  1733: >>>>>   4.703876094e+01 <=   5.722237620e+01  21.6% (37; 47)
# +  2131: >>>>>   4.715040760e+01 <=   5.374073233e+01  14.0% (36; 81)
# +  2392: mip =   4.715040760e+01 <=     tree is empty   0.0% (0; 257)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.5 secs
# Memory used: 16.4 Mb (17172334 bytes)
# Writing MIP solution to '/tmp/d155278c9b804cfb95d42e2895c6e0cf-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/4736c252f42440ff8d3e982d9a0f7d10-pulp.lp -o /tmp/4736c252f42440ff8d3e982d9a0f7d10-pulp.sol
# Reading problem data from '/tmp/4736c252f42440ff8d3e982d9a0f7d10-pulp.lp'...
# 44 rows, 10172 columns, 61049 non-zeros
# 10172 integer variables, all of which are binary
# 27439 lines were read
# GLPK Integer Optimizer 5.0
# 44 rows, 10172 columns, 61049 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10155 columns, 60930 non-zeros
# 10155 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10155 columns, 60930 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      67: obj =   4.119690897e+01 inf =   0.000e+00 (0)
# *   111: obj =   7.020567711e+01 inf =   9.728e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   111: mip =     not found yet <=              +inf        (1; 0)
# +   406: >>>>>   4.117439433e+01 <=   6.660532409e+01  61.8% (17; 6)
# +  1256: >>>>>   4.703876094e+01 <=   5.765511451e+01  22.6% (48; 36)
# +  1634: mip =   4.703876094e+01 <=     tree is empty   0.0% (0; 201)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.1 secs
# Memory used: 15.2 Mb (15941387 bytes)
# Writing MIP solution to '/tmp/4736c252f42440ff8d3e982d9a0f7d10-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/286b7e08383442a2a6f1813f435476d8-pulp.lp -o /tmp/286b7e08383442a2a6f1813f435476d8-pulp.sol
# Reading problem data from '/tmp/286b7e08383442a2a6f1813f435476d8-pulp.lp'...
# 45 rows, 10172 columns, 61050 non-zeros
# 10172 integer variables, all of which are binary
# 27440 lines were read
# GLPK Integer Optimizer 5.0
# 45 rows, 10172 columns, 61050 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10154 columns, 60924 non-zeros
# 10154 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10154 columns, 60924 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      70: obj =   4.977186598e+01 inf =   1.443e-15 (0)
# *   109: obj =   7.020567711e+01 inf =   2.328e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   109: mip =     not found yet <=              +inf        (1; 0)
# +   508: >>>>>   4.234411213e+01 <=   6.556051906e+01  54.8% (10; 7)
# +  1737: >>>>>   4.466076138e+01 <=   5.143331206e+01  15.2% (37; 74)
# +  1837: >>>>>   4.613963354e+01 <=   4.727662797e+01   2.5% (7; 128)
# +  1838: mip =   4.613963354e+01 <=     tree is empty   0.0% (0; 213)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.1 secs
# Memory used: 16.5 Mb (17309722 bytes)
# Writing MIP solution to '/tmp/286b7e08383442a2a6f1813f435476d8-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/78031826d48e40dc9be79f8f98e1be20-pulp.lp -o /tmp/78031826d48e40dc9be79f8f98e1be20-pulp.sol
# Reading problem data from '/tmp/78031826d48e40dc9be79f8f98e1be20-pulp.lp'...
# 46 rows, 10172 columns, 61051 non-zeros
# 10172 integer variables, all of which are binary
# 27441 lines were read
# GLPK Integer Optimizer 5.0
# 46 rows, 10172 columns, 61051 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10153 columns, 60918 non-zeros
# 10153 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10153 columns, 60918 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      67: obj =   4.338624784e+01 inf =   0.000e+00 (0)
# *   108: obj =   7.020567711e+01 inf =   3.290e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   108: mip =     not found yet <=              +inf        (1; 0)
# +   493: >>>>>   4.234411213e+01 <=   6.556051906e+01  54.8% (10; 7)
# +  1713: >>>>>   4.466076138e+01 <=   5.143331206e+01  15.2% (35; 74)
# +  1817: mip =   4.466076138e+01 <=     tree is empty   0.0% (0; 209)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 16.5 Mb (17317405 bytes)
# Writing MIP solution to '/tmp/78031826d48e40dc9be79f8f98e1be20-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/2eb8e38caa88409f974b96e1ceaf8096-pulp.lp -o /tmp/2eb8e38caa88409f974b96e1ceaf8096-pulp.sol
# Reading problem data from '/tmp/2eb8e38caa88409f974b96e1ceaf8096-pulp.lp'...
# 47 rows, 10172 columns, 61052 non-zeros
# 10172 integer variables, all of which are binary
# 27442 lines were read
# GLPK Integer Optimizer 5.0
# 47 rows, 10172 columns, 61052 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10152 columns, 60912 non-zeros
# 10152 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10152 columns, 60912 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      69: obj =   4.903395492e+01 inf =   0.000e+00 (0)
# *   110: obj =   7.020567711e+01 inf =   6.266e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   110: mip =     not found yet <=              +inf        (1; 0)
# +   497: >>>>>   4.234411213e+01 <=   6.556051906e+01  54.8% (10; 7)
# +  1847: mip =   4.234411213e+01 <=     tree is empty   0.0% (0; 209)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 16.5 Mb (17317056 bytes)
# Writing MIP solution to '/tmp/2eb8e38caa88409f974b96e1ceaf8096-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/7974ddf6e5a24f3ab56e5fb5f94a3f8f-pulp.lp -o /tmp/7974ddf6e5a24f3ab56e5fb5f94a3f8f-pulp.sol
# Reading problem data from '/tmp/7974ddf6e5a24f3ab56e5fb5f94a3f8f-pulp.lp'...
# 48 rows, 10172 columns, 61053 non-zeros
# 10172 integer variables, all of which are binary
# 27443 lines were read
# GLPK Integer Optimizer 5.0
# 48 rows, 10172 columns, 61053 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10151 columns, 60906 non-zeros
# 10151 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10151 columns, 60906 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      62: obj =   4.710586914e+01 inf =   0.000e+00 (0)
# *   100: obj =   7.020567711e+01 inf =   9.242e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   100: mip =     not found yet <=              +inf        (1; 0)
# +   617: >>>>>   4.099733902e+01 <=   6.470441342e+01  57.8% (25; 9)
# +  1118: >>>>>   4.203415367e+01 <=   5.815833883e+01  38.4% (35; 26)
# +  1881: mip =   4.203415367e+01 <=     tree is empty   0.0% (0; 215)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.2 secs
# Memory used: 16.4 Mb (17164099 bytes)
# Writing MIP solution to '/tmp/7974ddf6e5a24f3ab56e5fb5f94a3f8f-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/e872e2a3e54d46568a350f7429d230b1-pulp.lp -o /tmp/e872e2a3e54d46568a350f7429d230b1-pulp.sol
# Reading problem data from '/tmp/e872e2a3e54d46568a350f7429d230b1-pulp.lp'...
# 49 rows, 10172 columns, 61054 non-zeros
# 10172 integer variables, all of which are binary
# 27444 lines were read
# GLPK Integer Optimizer 5.0
# 49 rows, 10172 columns, 61054 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10150 columns, 60900 non-zeros
# 10150 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10150 columns, 60900 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      60: obj =   4.401610962e+01 inf =   6.291e-15 (0)
# *   101: obj =   7.020567711e+01 inf =   3.361e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   101: mip =     not found yet <=              +inf        (1; 0)
# +   760: >>>>>   3.479598872e+01 <=   6.499025931e+01  86.8% (43; 10)
# +  1566: >>>>>   4.072192016e+01 <=   5.341195141e+01  31.2% (52; 43)
# +  1981: >>>>>   4.099733902e+01 <=   4.545947533e+01  10.9% (19; 140)
# +  1992: >>>>>   4.117439433e+01 <=   4.501173263e+01   9.3% (15; 148)
# +  2018: mip =   4.117439433e+01 <=     tree is empty   0.0% (0; 239)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 18.1 Mb (18963166 bytes)
# Writing MIP solution to '/tmp/e872e2a3e54d46568a350f7429d230b1-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/d46e3f1099f54245b192bd49aa449502-pulp.lp -o /tmp/d46e3f1099f54245b192bd49aa449502-pulp.sol
# Reading problem data from '/tmp/d46e3f1099f54245b192bd49aa449502-pulp.lp'...
# 50 rows, 10172 columns, 61055 non-zeros
# 10172 integer variables, all of which are binary
# 27445 lines were read
# GLPK Integer Optimizer 5.0
# 50 rows, 10172 columns, 61055 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10149 columns, 60894 non-zeros
# 10149 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10149 columns, 60894 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      65: obj =   4.471297769e+01 inf =   0.000e+00 (0)
# *   107: obj =   7.020567711e+01 inf =   1.097e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   107: mip =     not found yet <=              +inf        (1; 0)
# +  1066: >>>>>   4.044937750e+01 <=   5.585900711e+01  38.1% (45; 24)
# +  1711: >>>>>   4.072192016e+01 <=   4.464337112e+01   9.6% (14; 129)
# +  1729: >>>>>   4.099733902e+01 <=   4.099733902e+01 < 0.1% (2; 181)
# +  1729: mip =   4.099733902e+01 <=     tree is empty   0.0% (0; 233)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.4 secs
# Memory used: 18.0 Mb (18841047 bytes)
# Writing MIP solution to '/tmp/d46e3f1099f54245b192bd49aa449502-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/06440c9866c545c6b03da276b3b778e0-pulp.lp -o /tmp/06440c9866c545c6b03da276b3b778e0-pulp.sol
# Reading problem data from '/tmp/06440c9866c545c6b03da276b3b778e0-pulp.lp'...
# 51 rows, 10172 columns, 61056 non-zeros
# 10172 integer variables, all of which are binary
# 27446 lines were read
# GLPK Integer Optimizer 5.0
# 51 rows, 10172 columns, 61056 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10148 columns, 60888 non-zeros
# 10148 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10148 columns, 60888 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      61: obj =   4.111050402e+01 inf =   0.000e+00 (0)
# *   110: obj =   7.020567711e+01 inf =   8.818e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   110: mip =     not found yet <=              +inf        (1; 0)
# +  1061: >>>>>   4.044937750e+01 <=   5.585900711e+01  38.1% (45; 24)
# +  1121: >>>>>   4.072192016e+01 <=   5.462303743e+01  34.1% (45; 31)
# +  1708: mip =   4.072192016e+01 <=     tree is empty   0.0% (0; 237)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 18.0 Mb (18840698 bytes)
# Writing MIP solution to '/tmp/06440c9866c545c6b03da276b3b778e0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/4c68338052be4c94ac0b60cbd5f055c4-pulp.lp -o /tmp/4c68338052be4c94ac0b60cbd5f055c4-pulp.sol
# Reading problem data from '/tmp/4c68338052be4c94ac0b60cbd5f055c4-pulp.lp'...
# 52 rows, 10172 columns, 61057 non-zeros
# 10172 integer variables, all of which are binary
# 27447 lines were read
# GLPK Integer Optimizer 5.0
# 52 rows, 10172 columns, 61057 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10147 columns, 60882 non-zeros
# 10147 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10147 columns, 60882 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      55: obj =   4.778347289e+01 inf =   4.266e-16 (0)
# *    97: obj =   7.020567711e+01 inf =   6.070e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    97: mip =     not found yet <=              +inf        (1; 0)
# +  1346: >>>>>   4.044937750e+01 <=   5.505503832e+01  36.1% (36; 39)
# +  1851: mip =   4.044937750e+01 <=     tree is empty   0.0% (0; 209)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.3 secs
# Memory used: 17.8 Mb (18660015 bytes)
# Writing MIP solution to '/tmp/4c68338052be4c94ac0b60cbd5f055c4-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/9ffaa1c5b74c4dc6a9b3c962699e8517-pulp.lp -o /tmp/9ffaa1c5b74c4dc6a9b3c962699e8517-pulp.sol
# Reading problem data from '/tmp/9ffaa1c5b74c4dc6a9b3c962699e8517-pulp.lp'...
# 53 rows, 10172 columns, 61058 non-zeros
# 10172 integer variables, all of which are binary
# 27448 lines were read
# GLPK Integer Optimizer 5.0
# 53 rows, 10172 columns, 61058 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10146 columns, 60876 non-zeros
# 10146 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10146 columns, 60876 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      66: obj =   5.029547215e+01 inf =   6.106e-16 (0)
# *   110: obj =   7.020567711e+01 inf =   2.483e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   110: mip =     not found yet <=              +inf        (1; 0)
# +  1810: >>>>>   3.479598872e+01 <=   5.385407190e+01  54.8% (74; 53)
# +  2231: mip =   3.479598872e+01 <=     tree is empty   0.0% (0; 265)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.7 secs
# Memory used: 17.5 Mb (18376222 bytes)
# Writing MIP solution to '/tmp/9ffaa1c5b74c4dc6a9b3c962699e8517-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/1fa89dfa645947b086b8db6b51b978d0-pulp.lp -o /tmp/1fa89dfa645947b086b8db6b51b978d0-pulp.sol
# Reading problem data from '/tmp/1fa89dfa645947b086b8db6b51b978d0-pulp.lp'...
# 54 rows, 10172 columns, 61059 non-zeros
# 10172 integer variables, all of which are binary
# 27449 lines were read
# GLPK Integer Optimizer 5.0
# 54 rows, 10172 columns, 61059 non-zeros
# 10172 integer variables, all of which are binary
# Preprocessing...
# 27 rows, 10145 columns, 60870 non-zeros
# 10145 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 27
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 27 rows, 10145 columns, 60870 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+01 (6)
#      60: obj =   4.867726293e+01 inf =   8.360e-15 (0)
# *   110: obj =   7.020567711e+01 inf =   3.843e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   110: mip =     not found yet <=              +inf        (1; 0)
# +  2797: mip =     not found yet <=     tree is empty        (0; 267)
# PROBLEM HAS NO INTEGER FEASIBLE SOLUTION
# Time used:   1.9 secs
# Memory used: 18.4 Mb (19315315 bytes)
# Writing MIP solution to '/tmp/1fa89dfa645947b086b8db6b51b978d0-pulp.sol'...

# %%
solutions
# Out:
# [['dwarf', 'glyph', 'jocks', 'muntz', 'vibex'],
#  ['breck', 'flows', 'japyx', 'vingt', 'zhmud'],
#  ['fjord', 'glyph', 'muntz', 'vibex', 'wacks'],
#  ['brews', 'flock', 'japyx', 'vingt', 'zhmud'],
#  ['brows', 'fleck', 'japyx', 'vingt', 'zhmud'],
#  ['breck', 'fowls', 'japyx', 'vingt', 'zhmud'],
#  ['blows', 'freck', 'japyx', 'vingt', 'zhmud'],
#  ['bowls', 'freck', 'japyx', 'vingt', 'zhmud'],
#  ['breck', 'japyx', 'vingt', 'wolfs', 'zhmud'],
#  ['dhikr', 'expwy', 'fultz', 'gconv', 'jambs'],
#  ['brock', 'flews', 'japyx', 'vingt', 'zhmud'],
#  ['flong', 'japyx', 'twick', 'verbs', 'zhmud'],
#  ['dumbs', 'fritz', 'gconv', 'japyx', 'whelk'],
#  ['becks', 'fultz', 'japyx', 'mordv', 'whing'],
#  ['frack', 'jowly', 'pbxes', 'vingt', 'zhmud'],
#  ['blitz', 'fconv', 'gryph', 'judex', 'mawks'],
#  ['block', 'fremt', 'japyx', 'vughs', 'windz'],
#  ['bovld', 'freck', 'japyx', 'muntz', 'whigs'],
#  ['chivw', 'expdt', 'flank', 'grosz', 'jumby'],
#  ['flong', 'jarvy', 'pbxes', 'twick', 'zhmud'],
#  ['expdt', 'gconv', 'jumby', 'whilk', 'zarfs'],
#  ['bongs', 'chivw', 'fremd', 'japyx', 'klutz'],
#  ['ampyx', 'bortz', 'chivw', 'fjeld', 'gunks'],
#  ['bilks', 'fconv', 'grewt', 'japyx', 'zhmud'],
#  ['bocks', 'flegm', 'japyx', 'thruv', 'windz'],
#  ['chivw', 'expdt', 'flamb', 'grosz', 'junky'],
#  ['chivw', 'expdt', 'jumby', 'klong', 'zarfs']]
